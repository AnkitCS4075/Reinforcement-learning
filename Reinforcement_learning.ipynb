# %%
# !pip install stable-baselines3[extra]
# Out:
# Requirement already satisfied: stable-baselines3[extra] in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (1.1.0)
# Requirement already satisfied: numpy in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (1.21.2)
# Requirement already satisfied: matplotlib in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (3.4.1)
# Requirement already satisfied: cloudpickle in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (1.6.0)
# Requirement already satisfied: torch>=1.4.0 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (1.8.1+cu111)
# Requirement already satisfied: pandas in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (1.2.4)
# Requirement already satisfied: gym>=0.17 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (0.18.3)
# Requirement already satisfied: opencv-python in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (4.5.1.48)
# Requirement already satisfied: psutil in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (5.8.0)
# Requirement already satisfied: pillow in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (8.2.0)
# Requirement already satisfied: atari-py~=0.2.0 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (0.2.9)
# Requirement already satisfied: tensorboard>=2.2.0 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from stable-baselines3[extra]) (2.5.0)
# Requirement already satisfied: six in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from atari-py~=0.2.0->stable-baselines3[extra]) (1.15.0)
# Requirement already satisfied: pyglet<=1.5.15,>=1.4.0 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from gym>=0.17->stable-baselines3[extra]) (1.5.15)
# Requirement already satisfied: scipy in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from gym>=0.17->stable-baselines3[extra]) (1.6.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.6.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.36.2)
# Requirement already satisfied: absl-py>=0.4 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.12.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (2.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.29.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (2.25.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (3.3.4)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (49.2.1)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.34.1)
# Requirement already satisfied: protobuf>=3.6.0 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (3.15.8)
# Requirement already satisfied: typing-extensions in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from torch>=1.4.0->stable-baselines3[extra]) (3.7.4.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.10.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from pandas->stable-baselines3[extra]) (2021.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (4.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->stable-baselines3[extra]) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->stable-baselines3[extra]) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->stable-baselines3[extra]) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->stable-baselines3[extra]) (4.0.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[extra]) (3.1.0)

# %%
import gym 
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # Load Environment

# %%
environment_name = "CartPole-v0"

# %%
env = gym.make(environment_name)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close() # To close down the render frame
# Out:
# Episode:1 Score:23.0
# Episode:2 Score:21.0
# Episode:3 Score:22.0
# Episode:4 Score:48.0
# Episode:5 Score:38.0

# %%
env.reset() # reset the environment and obtain intial observations
# Out:
# array([-0.01236899, -0.037256  ,  0.0390576 ,  0.0159925 ])

# %%
env.render() # Used to visualize the environment
# Out:
# True

# %%
env.action_space 
# output : Discrete(2) means either 0 or 1
# Out:
# Discrete(2)

# %%
env.action_space.sample()  # It will randomly choose either 0 or 1
# Out:
# 1

# %%
env.observation_space
# Out:
# Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)

# %%
env.observation_space.sample()
# Out:
# array([-8.4233397e-01,  2.9248454e+38, -3.8003543e-01, -1.0028530e+37],
#       dtype=float32)

# %%
env.step(1) # apply an action to the environment
# env.step returns four parameters, namely observation, reward, done and info.
# Out:
# (array([-0.01311411,  0.15728468,  0.03937745, -0.26411597]), 1.0, False, {})

# %% [markdown]
# # Train an RL model

# %%
log_path = os.path.join('Training', 'Logs')

# %%
log_path
# Out:
# 'Training\\Logs'

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cuda device

# %%
model.learn(total_timesteps=20000)
# Out:
# Exception ignored in: <function Viewer.__del__ at 0x00000163F1379820>
# Traceback (most recent call last):
#   File "c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages\gym\envs\classic_control\rendering.py", line 165, in __del__
#     self.close()
#   File "c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages\gym\envs\classic_control\rendering.py", line 83, in close
#     self.window.close()
#   File "c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages\pyglet\window\win32\__init__.py", line 319, in close
#     super(Win32Window, self).close()
#   File "c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages\pyglet\window\__init__.py", line 838, in close
#     app.windows.remove(self)
#   File "c:\users\ankit\appdata\local\programs\python\python39\lib\_weakrefset.py", line 110, in remove
#     self.data.remove(ref(item))
# KeyError: <weakref at 0x00000163F74D1D10; to 'Win32Window' at 0x00000163F63D7E80>
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2
# Logging to Training\Logs\PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 144  |
# |    iterations      | 1    |
# |    time_elapsed    | 14   |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 189         |
# |    iterations           | 2           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009104459 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.00483    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.55        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0203     |
# |    value_loss           | 57.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 3           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011261553 |
# |    clip_fraction        | 0.0864      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.662      |
# |    explained_variance   | 0.0826      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.6        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0216     |
# |    value_loss           | 32.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 4           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009013889 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.63       |
# |    explained_variance   | 0.243       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.9        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0201     |
# |    value_loss           | 48.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 208          |
# |    iterations           | 5            |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0071371146 |
# |    clip_fraction        | 0.0839       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.6         |
# |    explained_variance   | 0.21         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.3         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0174      |
# |    value_loss           | 57           |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 6           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007246249 |
# |    clip_fraction        | 0.0765      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.593      |
# |    explained_variance   | 0.572       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.2        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 45          |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 203        |
# |    iterations           | 7          |
# |    time_elapsed         | 70         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01039348 |
# |    clip_fraction        | 0.135      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.583     |
# |    explained_variance   | 0.806      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 15.6       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0175    |
# |    value_loss           | 33.6       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 190         |
# |    iterations           | 8           |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011208933 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.58       |
# |    explained_variance   | 0.82        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.32        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0158     |
# |    value_loss           | 37.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 181          |
# |    iterations           | 9            |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0038907095 |
# |    clip_fraction        | 0.0448       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.568       |
# |    explained_variance   | 0.661        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.9         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00657     |
# |    value_loss           | 59.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 10          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.005997233 |
# |    clip_fraction        | 0.0789      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.564      |
# |    explained_variance   | 0.699       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.91        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00885    |
# |    value_loss           | 61.1        |
# -----------------------------------------

# %% [markdown]
# # Save and Reload model

# %%
PPO_Path = os.path.join('Training', 'Saved Models', 'PP_Model_Cartpole')

# %%
model.save(PPO_Path)

# %%
del model

# %%
model = PPO.load(PPO_Path, env=env)

# %%
model.learn(total_timesteps=1000)
# Out:
# Logging to Training\Logs\PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 508  |
# |    iterations      | 1    |
# |    time_elapsed    | 4    |
# |    total_timesteps | 2048 |
# -----------------------------

# %% [markdown]
# # Evaluation

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# c:\users\ankit\appdata\local\programs\python\python39\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (200.0, 0.0)

# %%
env.close()

# %% [markdown]
# # Test model

# %%
model.predict(obs)
# Out:
# (array([0], dtype=int64), None)

# %%
action , _ = model.predict(obs)

# %%
action
# Out:
# array([1], dtype=int64)

# %%
episodes = 5
for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close() # To close down the render frame
# Out:
# Episode:1 Score:[200.]
# Episode:2 Score:[200.]
# Episode:3 Score:[76.]
# Episode:4 Score:[200.]
# Episode:5 Score:[178.]

# %%
obs = env.reset()

# %%
obs
# Out:
# array([[-0.00392499,  0.03335889, -0.00611641,  0.03700055]],
#       dtype=float32)

# %%
action, _ = model.predict(obs)

# %%
env.action_space.sample()
# Out:
# 1

# %%
env.step(action) # As step returns four parameteres i.s observations, reward, done, info
# Out:
# (array([[-0.00325781, -0.16167483, -0.00537639,  0.32774743]],
#        dtype=float32),
#  array([1.], dtype=float32),
#  array([False]),
#  [{}])

# %% [markdown]
# # Viewing Logs in Tensorboard

# %%
training_log_path = os.path.join(log_path, 'PPO_2')

# %%
training_log_path
# Out:
# 'Training\\Logs\\PPO_2'

# %%
# !tensorboard --logdir= {training_log_path}
# Out:
# 2021-10-30 23:23:56.339638: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cudart64_110.dll
# usage: tensorboard [-h] [--helpfull] [--logdir PATH] [--logdir_spec PATH_SPEC]
#                    [--host ADDR] [--bind_all] [--port PORT]
#                    [--reuse_port BOOL] [--load_fast {false,auto,true}]
#                    [--extra_data_server_flags EXTRA_DATA_SERVER_FLAGS]
#                    [--grpc_creds_type {local,ssl,ssl_dev}]
#                    [--grpc_data_provider PORT] [--purge_orphaned_data BOOL]
#                    [--db URI] [--db_import] [--inspect] [--version_tb]
#                    [--tag TAG] [--event_file PATH] [--path_prefix PATH]
#                    [--window_title TEXT] [--max_reload_threads COUNT]
#                    [--reload_interval SECONDS] [--reload_task TYPE]
#                    [--reload_multifile BOOL]
#                    [--reload_multifile_inactive_secs SECONDS]
#                    [--generic_data TYPE]
#                    [--samples_per_plugin SAMPLES_PER_PLUGIN]
#                    [--whatif-use-unsafe-custom-prediction YOUR_CUSTOM_PREDICT_FUNCTION.py]
#                    [--whatif-data-dir PATH]
#                    {serve,dev} ...
# tensorboard: error: invalid choice: 'Training\\Logs\\PPO_2' (choose from 'serve', 'dev')

# %% [markdown]
# # Adding a callback to the training stage

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training', 'Saved Models')

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=200, verbose=1)
eval_callback = EvalCallback(env, callback_on_new_best=stop_callback, eval_freq=10000, best_model_save_path=save_path, verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cuda device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_3
# -----------------------------
# | time/              |      |
# |    fps             | 536  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009245167 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00204     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.44        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 53.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 3           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008371154 |
# |    clip_fraction        | 0.0486      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.669      |
# |    explained_variance   | 0.0606      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.7        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 40.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 366         |
# |    iterations           | 4           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008232165 |
# |    clip_fraction        | 0.0839      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.634      |
# |    explained_variance   | 0.21        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.9        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0199     |
# |    value_loss           | 52.5        |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=189.00 +/- 16.30
# Episode length: 189.00 +/- 16.30
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 189         |
# |    mean_reward          | 189         |
# | time/                   |             |
# |    total timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.008067088 |
# |    clip_fraction        | 0.077       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.61       |
# |    explained_variance   | 0.311       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.5        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 58.9        |
# -----------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 346   |
# |    iterations      | 5     |
# |    time_elapsed    | 29    |
# |    total_timesteps | 10240 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 341          |
# |    iterations           | 6            |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0071487296 |
# |    clip_fraction        | 0.0704       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.595       |
# |    explained_variance   | 0.427        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.2         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0143      |
# |    value_loss           | 60.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 7           |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.005508855 |
# |    clip_fraction        | 0.0397      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.579      |
# |    explained_variance   | 0.417       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.3        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00793    |
# |    value_loss           | 68          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 326         |
# |    iterations           | 8           |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006711702 |
# |    clip_fraction        | 0.0726      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.593      |
# |    explained_variance   | 0.65        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.1        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00919    |
# |    value_loss           | 48.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 321          |
# |    iterations           | 9            |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0046820175 |
# |    clip_fraction        | 0.0391       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.57        |
# |    explained_variance   | 0.582        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 48.4         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00572     |
# |    value_loss           | 73.9         |
# ------------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.005717607 |
# |    clip_fraction        | 0.035       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.561      |
# |    explained_variance   | 0.829       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.8        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00567    |
# |    value_loss           | 40.8        |
# -----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 200.00  is above the threshold 200

# %% [markdown]
# # Changing Policies

# %%
net_arch = [dict(pi=[128,128,128,128,128], vf=[128,128,128,128])]

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path, policy_kwargs={'net_arch':net_arch})
# Out:
# Using cuda device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_4
# -----------------------------
# | time/              |      |
# |    fps             | 415  |
# |    iterations      | 1    |
# |    time_elapsed    | 4    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 308        |
# |    iterations           | 2          |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01600798 |
# |    clip_fraction        | 0.248      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.681     |
# |    explained_variance   | 0.0037     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.96       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0299    |
# |    value_loss           | 20.4       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 282         |
# |    iterations           | 3           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016676014 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.638      |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.1        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0305     |
# |    value_loss           | 32.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 270         |
# |    iterations           | 4           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013413459 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.583      |
# |    explained_variance   | 0.405       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.9        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0228     |
# |    value_loss           | 47.7        |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.010119951 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.551      |
# |    explained_variance   | 0.62        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.1        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 39.4        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 245   |
# |    iterations      | 5     |
# |    time_elapsed    | 41    |
# |    total_timesteps | 10240 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 241          |
# |    iterations           | 6            |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0064515527 |
# |    clip_fraction        | 0.0902       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.539       |
# |    explained_variance   | 0.69         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14           |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00644     |
# |    value_loss           | 29.2         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 228         |
# |    iterations           | 7           |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.007784753 |
# |    clip_fraction        | 0.0494      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.527      |
# |    explained_variance   | 0.614       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.7        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00165    |
# |    value_loss           | 56.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 196         |
# |    iterations           | 8           |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005298106 |
# |    clip_fraction        | 0.0476      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.517      |
# |    explained_variance   | 0.575       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.6        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00262    |
# |    value_loss           | 59.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 176         |
# |    iterations           | 9           |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008003081 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.529      |
# |    explained_variance   | 0.884       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.52        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00963    |
# |    value_loss           | 23.4        |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0041247024 |
# |    clip_fraction        | 0.0605       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.501       |
# |    explained_variance   | 0.624        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.1         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00313     |
# |    value_loss           | 95.3         |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 159   |
# |    iterations      | 10    |
# |    time_elapsed    | 128   |
# |    total_timesteps | 20480 |
# ------------------------------

# %% [markdown]
# # Using an alternate Algorithm

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cuda device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training\Logs\DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.97     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 2919     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 64       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.933    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 4072     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 142      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.896    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 4884     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 219      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.852    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 5692     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 312      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.809    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 6126     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 403      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.774    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 6367     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 476      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.737    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 6616     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 554      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.679    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 7135     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 676      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.634    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 7284     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 770      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.606    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 7168     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 829      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.581    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 7200     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 883      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.548    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 7281     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 951      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.512    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 7417     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1028     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.479    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 7529     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1096     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.422    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 7675     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1217     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.374    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 7815     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1317     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.296    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 7989     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1482     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.256    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 8093     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1566     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.212    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 8149     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1658     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.16     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 8213     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1769     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.105    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 8285     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1884     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.0737   |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 8182     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1950     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 8265     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2069     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 8278     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2163     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 8291     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2241     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 8314     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2297     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 8361     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2393     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 8386     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2459     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 8361     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2543     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 8361     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2635     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 8346     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2705     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 8375     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2798     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 8421     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2889     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 8529     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3028     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 8592     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3205     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 8603     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3312     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 8648     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3441     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 8653     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3521     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 8673     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3607     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 8666     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3673     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 8688     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3752     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 8725     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3829     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 8773     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3946     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 8801     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4038     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 8791     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4121     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 8804     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4197     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 8863     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4349     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 8877     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4462     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 8895     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4551     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 8942     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4673     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 8968     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4758     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 8979     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4827     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 9074     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5014     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 9093     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5124     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 9094     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5188     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 9091     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5259     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 9090     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5340     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 9056     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5419     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 9055     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5491     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 9052     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5588     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 9059     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5692     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 9055     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5825     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 9047     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5928     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 9026     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5995     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 8996     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6074     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 8995     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6172     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 8970     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6307     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 8957     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6387     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 8949     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6480     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 8968     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6592     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 8956     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6672     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 8922     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6745     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 8911     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6808     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 8945     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6932     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 8982     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7095     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 9004     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7238     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 9020     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7332     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 9022     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7406     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 9044     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7505     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 9030     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7565     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 9038     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7626     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 9027     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7698     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 9122     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7943     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 9136     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8028     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 9146     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8127     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 9125     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8245     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 9144     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8327     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 9144     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8390     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 9149     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8450     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 9142     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8525     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 9137     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8575     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 9147     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8667     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 9154     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8737     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 9153     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8800     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 9167     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8887     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 9181     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9010     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 9172     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9084     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 9189     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9174     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 9187     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9245     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 9180     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9339     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 9173     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9478     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 9147     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9579     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 9125     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9647     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 9105     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9716     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 9084     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9776     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 9073     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9845     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 9063     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9916     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 9055     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9970     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 7013     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10038    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 7015     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10118    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 7025     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10203    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 7050     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10302    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 7067     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10390    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 7081     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10474    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 7102     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10569    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 7123     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10686    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 7114     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10764    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 7118     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10842    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 7120     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10922    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 7162     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11080    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 7165     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11142    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 7185     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11238    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 7199     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11316    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 7215     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11406    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 7217     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11453    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 7236     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11540    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 7248     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11646    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 7256     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11718    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 7270     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11791    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 7291     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11890    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 7296     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 7301     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12009    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 7308     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12085    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 7325     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12173    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 7330     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12253    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 7343     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12348    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 7352     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12408    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 7371     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12513    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 7384     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12594    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 7388     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12645    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 7398     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12736    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 7408     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12813    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 7419     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12891    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 7420     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12960    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 7435     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13052    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 7443     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13118    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 7454     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13197    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 7469     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13283    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 7487     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13389    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 7503     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13493    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 7517     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13594    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 7521     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13661    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 692      |
# |    fps              | 7663     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 15478    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 696      |
# |    fps              | 7668     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 15573    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 7683     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 15687    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 704      |
# |    fps              | 7686     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 15764    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 7686     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 15847    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 7686     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 15925    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 7697     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16031    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 7710     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16136    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 7725     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16243    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 7734     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16331    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 7738     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16418    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 7749     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 7754     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16621    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 7756     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16703    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 7766     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 752      |
# |    fps              | 7768     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16860    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 756      |
# |    fps              | 7777     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16957    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 7785     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 17029    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 764      |
# |    fps              | 7810     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 17200    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 7821     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 17294    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 772      |
# |    fps              | 7821     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 17373    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 776      |
# |    fps              | 7839     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 17500    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 7858     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 17629    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 784      |
# |    fps              | 7863     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 17693    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 788      |
# |    fps              | 7862     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 17755    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 7873     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 17843    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 796      |
# |    fps              | 7879     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 17935    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 7887     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18008    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 7896     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18090    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 808      |
# |    fps              | 7911     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18212    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 812      |
# |    fps              | 7919     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18285    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 7929     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18373    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 7940     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18454    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 7945     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18504    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 7956     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18625    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 7966     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18712    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 7978     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18820    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 7982     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18876    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 7988     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18940    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 7991     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18995    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 7999     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19081    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 8009     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19176    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 8012     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19265    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 8020     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19339    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 8024     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19420    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 8030     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19483    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 8040     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19595    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 8051     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19680    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 884      |
# |    fps              | 8060     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19773    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 888      |
# |    fps              | 8068     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19865    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 892      |
# |    fps              | 8076     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19958    |
# ----------------------------------

# %%
from stable_baselines3 import A2C

# %%
model = A2C('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cuda device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training\Logs\A2C_1
# ------------------------------------
# | time/                 |          |
# |    fps                | 275      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.67    |
# |    explained_variance | 0.381    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 1.05     |
# |    value_loss         | 2.93     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 259      |
# |    iterations         | 200      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.68    |
# |    explained_variance | -0.0576  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 1.82     |
# |    value_loss         | 7.68     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 300      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.595   |
# |    explained_variance | -0.0533  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 1.61     |
# |    value_loss         | 7.19     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 251      |
# |    iterations         | 400      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.573   |
# |    explained_variance | -0.00564 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 1.54     |
# |    value_loss         | 5.92     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 254      |
# |    iterations         | 500      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.622   |
# |    explained_variance | 0.00305  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 1.33     |
# |    value_loss         | 5.27     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 255      |
# |    iterations         | 600      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.627   |
# |    explained_variance | 0.00277  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 1.24     |
# |    value_loss         | 4.67     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 700       |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -0.57     |
# |    explained_variance | -0.000244 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -10.8     |
# |    value_loss         | 771       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 259       |
# |    iterations         | 800       |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -0.638    |
# |    explained_variance | -0.000182 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | 0.863     |
# |    value_loss         | 3.61      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 260      |
# |    iterations         | 900      |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.574   |
# |    explained_variance | 0.000914 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -25      |
# |    value_loss         | 1.52e+03 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 1000      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -0.606    |
# |    explained_variance | -0.000165 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 0.635     |
# |    value_loss         | 2.65      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 262      |
# |    iterations         | 1100     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.641   |
# |    explained_variance | 0.000488 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.572    |
# |    value_loss         | 2.21     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 264      |
# |    iterations         | 1200     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.661   |
# |    explained_variance | 1.89e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.612    |
# |    value_loss         | 1.83     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 264      |
# |    iterations         | 1300     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.685   |
# |    explained_variance | -0.00011 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.705    |
# |    value_loss         | 1.5      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 264      |
# |    iterations         | 1400     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.601   |
# |    explained_variance | 0.000273 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.321    |
# |    value_loss         | 1.23     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 264       |
# |    iterations         | 1500      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -0.549    |
# |    explained_variance | -3.15e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 0.455     |
# |    value_loss         | 0.954     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 264      |
# |    iterations         | 1600     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.488   |
# |    explained_variance | 0.000243 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.405    |
# |    value_loss         | 0.715    |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 264       |
# |    iterations         | 1700      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -0.677    |
# |    explained_variance | -8.76e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | 0.451     |
# |    value_loss         | 0.575     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 263      |
# |    iterations         | 1800     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.634   |
# |    explained_variance | 2.2e-05  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -4.84    |
# |    value_loss         | 1.25e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 1900     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.591   |
# |    explained_variance | 0.000133 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.411    |
# |    value_loss         | 0.286    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 2000     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.593   |
# |    explained_variance | 0.000103 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.169    |
# |    value_loss         | 0.158    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 225      |
# |    iterations         | 2100     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -0.584   |
# |    explained_variance | 0.000156 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 0.106    |
# |    value_loss         | 0.068    |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 217       |
# |    iterations         | 2200      |
# |    time_elapsed       | 50        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -0.61     |
# |    explained_variance | -0.000118 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | 0.0702    |
# |    value_loss         | 0.0169    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 210       |
# |    iterations         | 2300      |
# |    time_elapsed       | 54        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -0.582    |
# |    explained_variance | -4.29e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | 0.00995   |
# |    value_loss         | 0.000509  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 203      |
# |    iterations         | 2400     |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.632   |
# |    explained_variance | 0.0182   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.00163  |
# |    value_loss         | 1.12e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 198      |
# |    iterations         | 2500     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.576   |
# |    explained_variance | 0.0038   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.00214  |
# |    value_loss         | 1.6e-05  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 193       |
# |    iterations         | 2600      |
# |    time_elapsed       | 67        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -0.557    |
# |    explained_variance | -4.21e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | 0.000696  |
# |    value_loss         | 1.55e-06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 189      |
# |    iterations         | 2700     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -0.562   |
# |    explained_variance | -0.00511 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.00313  |
# |    value_loss         | 2.49e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 185      |
# |    iterations         | 2800     |
# |    time_elapsed       | 75       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.56    |
# |    explained_variance | 0.144    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.000894 |
# |    value_loss         | 2.78e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 182      |
# |    iterations         | 2900     |
# |    time_elapsed       | 79       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.48    |
# |    explained_variance | 0.0254   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.000105 |
# |    value_loss         | 3.54e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 178      |
# |    iterations         | 3000     |
# |    time_elapsed       | 83       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.636   |
# |    explained_variance | -0.0273  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.000422 |
# |    value_loss         | 8.89e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 176      |
# |    iterations         | 3100     |
# |    time_elapsed       | 87       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.574   |
# |    explained_variance | -0.00753 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 0.000347 |
# |    value_loss         | 3.67e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 173      |
# |    iterations         | 3200     |
# |    time_elapsed       | 92       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.576   |
# |    explained_variance | -0.276   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 7.61e-05 |
# |    value_loss         | 4.1e-08  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 171      |
# |    iterations         | 3300     |
# |    time_elapsed       | 96       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.524   |
# |    explained_variance | -0.0604  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.000704 |
# |    value_loss         | 1.77e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 169      |
# |    iterations         | 3400     |
# |    time_elapsed       | 100      |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.494   |
# |    explained_variance | -40.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 5.32e-05 |
# |    value_loss         | 4.34e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 167      |
# |    iterations         | 3500     |
# |    time_elapsed       | 104      |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -0.538   |
# |    explained_variance | 0.171    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.000301 |
# |    value_loss         | 5.07e-07 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 165       |
# |    iterations         | 3600      |
# |    time_elapsed       | 108       |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -0.604    |
# |    explained_variance | -0.000818 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | 0.000687  |
# |    value_loss         | 2.68e-06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 164      |
# |    iterations         | 3700     |
# |    time_elapsed       | 112      |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.637   |
# |    explained_variance | 0.0136   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.00035  |
# |    value_loss         | 8.87e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 162      |
# |    iterations         | 3800     |
# |    time_elapsed       | 116      |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.571   |
# |    explained_variance | -10.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -0.00121 |
# |    value_loss         | 2.17e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 3900     |
# |    time_elapsed       | 120      |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -0.558   |
# |    explained_variance | 0.0426   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.000105 |
# |    value_loss         | 5.23e-08 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 160      |
# |    iterations         | 4000     |
# |    time_elapsed       | 124      |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.573   |
# |    explained_variance | -0.0846  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.000682 |
# |    value_loss         | 1.19e-06 |
# ------------------------------------

# %% [markdown]
# Similarly we can do for other RL Algorithms such as DDPG, HER, SAC, TD3
